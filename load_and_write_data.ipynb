# %%
import eurostat
import pandas as pd
import os
import numpy as np

# %%
aact_eaa01 = eurostat.get_data_df('aact_eaa01')

# %%
aact_eaa01.head()
# Out:
#   freq itm_newa indic_ag     unit geo\TIME_PERIOD  1973  1974  1975  1976  \
# 0    A    01000  PROD_BP  MIO_EUR              AT   NaN   NaN   NaN   NaN
# 1    A    01000  PROD_BP  MIO_EUR              BE   NaN   NaN   NaN   NaN
# 2    A    01000  PROD_BP  MIO_EUR              BG   NaN   NaN   NaN   NaN
# 3    A    01000  PROD_BP  MIO_EUR              CH   NaN   NaN   NaN   NaN
# 4    A    01000  PROD_BP  MIO_EUR              CY   NaN   NaN   NaN   NaN
#
#    1977  ...     2012     2013     2014     2015     2016     2017     2018  \
# 0   NaN  ...  1029.21   717.58   769.41   728.38   749.33   754.06   776.48
# 1   NaN  ...   606.09   513.17   451.63   453.76   305.91   376.77   417.79
# 2   NaN  ...  1311.49  1258.57  1330.84  1228.73  1199.37  1246.43  1443.72
# 3   NaN  ...   308.64   279.29   303.51   347.50   276.16   341.44   298.10
# 4   NaN  ...    10.71    12.52     1.83    18.65     3.19     7.18     5.84
#
#       2019     2020     2021
# 0   801.97   834.08  1147.54
# 1   435.90   490.13   696.71
# 2  1499.80  1333.72  2264.71
# 3   340.27   381.95   324.48
# 4    12.64    12.29    11.60
#
# [5 rows x 54 columns]

# %%
aact_eaa01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57400 entries, 0 to 57399
# Data columns (total 54 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   freq             57400 non-null  object
#  1   itm_newa         57400 non-null  object
#  2   indic_ag         57400 non-null  object
#  3   unit             57400 non-null  object
#  4   geo\TIME_PERIOD  57400 non-null  object
#  5   1973             3310 non-null   float64
#  6   1974             3316 non-null   float64
#  7   1975             4672 non-null   float64
#  8   1976             5121 non-null   float64
#  9   1977             5142 non-null   float64
#  10  1978             5142 non-null   float64
#  11  1979             5142 non-null   float64
#  12  1980             8799 non-null   float64
#  13  1981             8805 non-null   float64
#  14  1982             8811 non-null   float64
#  15  1983             8814 non-null   float64
#  16  1984             8817 non-null   float64
#  17  1985             10429 non-null  float64
#  18  1986             11935 non-null  float64
#  19  1987             11932 non-null  float64
#  20  1988             11938 non-null  float64
#  21  1989             11938 non-null  float64
#  22  1990             15683 non-null  float64
#  23  1991             20622 non-null  float64
#  24  1992             20622 non-null  float64
#  25  1993             26010 non-null  float64
#  26  1994             26001 non-null  float64
#  27  1995             30693 non-null  float64
#  28  1996             30708 non-null  float64
#  29  1997             31536 non-null  float64
#  30  1998             42658 non-null  float64
#  31  1999             42304 non-null  float64
#  32  2000             42454 non-null  float64
#  33  2001             42421 non-null  float64
#  34  2002             42439 non-null  float64
#  35  2003             42559 non-null  float64
#  36  2004             42847 non-null  float64
#  37  2005             46735 non-null  float64
#  38  2006             46645 non-null  float64
#  39  2007             48790 non-null  float64
#  40  2008             48754 non-null  float64
#  41  2009             48691 non-null  float64
#  42  2010             48010 non-null  float64
#  43  2011             47884 non-null  float64
#  44  2012             47854 non-null  float64
#  45  2013             47812 non-null  float64
#  46  2014             47830 non-null  float64
#  47  2015             46438 non-null  float64
#  48  2016             46474 non-null  float64
#  49  2017             43774 non-null  float64
#  50  2018             42439 non-null  float64
#  51  2019             42502 non-null  float64
#  52  2020             37203 non-null  float64
#  53  2021             36594 non-null  float64
# dtypes: float64(49), object(5)
# memory usage: 23.6+ MB

# %%
os_gva = aact_eaa01[(aact_eaa01.itm_newa.isin(['20000', '27000'])) & (aact_eaa01.indic_ag == 'PROD_BP') 
                                                                   & (aact_eaa01.unit == 'MIO_EUR')]

# %%
os_gva.head()
# Out:
#       freq itm_newa indic_ag     unit geo\TIME_PERIOD  1973  1974  1975  1976  \
# 52588    A    20000  PROD_BP  MIO_EUR              AT   NaN   NaN   NaN   NaN
# 52589    A    20000  PROD_BP  MIO_EUR              BE   NaN   NaN   NaN   NaN
# 52590    A    20000  PROD_BP  MIO_EUR              BG   NaN   NaN   NaN   NaN
# 52591    A    20000  PROD_BP  MIO_EUR              CH   NaN   NaN   NaN   NaN
# 52592    A    20000  PROD_BP  MIO_EUR              CY   NaN   NaN   NaN   NaN
#
#        1977  ...     2012     2013     2014     2015     2016     2017  \
# 52588   NaN  ...  2981.66  2754.18  2728.85  2705.44  2859.12  3221.72
# 52589   NaN  ...  2825.40  2408.47  2244.58  2485.08  2238.38  2471.83
# 52590   NaN  ...  1662.26  1694.36  1731.65  1620.73  1675.58  1792.38
# 52591   NaN  ...  3093.42  3168.18  3500.61  3516.31  3719.59  3502.41
# 52592   NaN  ...   332.81   320.67   267.73   273.54   318.80   321.16
#
#           2018     2019     2020     2021
# 52588  3114.61  3050.94  3122.27  3622.44
# 52589  2225.64  2627.23  2472.33  2570.95
# 52590  1732.50  1767.81  1748.41  2640.07
# 52591  3561.20  3816.50  4179.41  3881.48
# 52592   308.38   348.05   362.26   331.89
#
# [5 rows x 54 columns]

# %%
os_gva.to_csv('os_gva.csv')

# %%
apro_cpsh1 = eurostat.get_data_df('apro_cpsh1')

# %%
apro_cpsh1.head()
# Out:
#   freq crops strucpro geo\TIME_PERIOD     2000     2001     2002     2003  \
# 0    A   ARA       MA              AL   519.30   400.60   395.60   399.30
# 1    A   ARA       MA              AT  1381.10  1379.00  1378.40  1379.30
# 2    A   ARA       MA              BA   662.04   653.56   636.37   605.95
# 3    A   ARA       MA              BE   867.00   845.90   833.10   832.90
# 4    A   ARA       MA              BG  3467.50  3399.10  3331.00  3282.20
#
#       2004     2005  ...     2013     2014     2015     2016     2017  \
# 0   384.80      NaN  ...      NaN   408.90   413.00   620.30   612.00
# 1  1378.00  1379.40  ...  1353.97  1351.66  1346.02  1336.49  1328.87
# 2   613.28   609.53  ...   573.93   560.14   578.35   595.37   594.00
# 3   840.00   843.30  ...   818.00   819.00   836.37   855.41   841.91
# 4  3296.80      NaN  ...  3462.12  3469.39  3494.08  3481.49  3474.32
#
#       2018     2019     2020    2021  2022
# 0   611.00   610.20   599.60  599.90   NaN
# 1  1327.15  1325.53  1321.71     NaN   NaN
# 2   597.29   604.95   618.45     NaN   NaN
# 3   856.83   863.55   869.34  870.42   NaN
# 4  3463.67  3462.11  3478.01     NaN   NaN
#
# [5 rows x 27 columns]

# %%
yields = apro_cpsh1[apro_cpsh1.strucpro == 'YI_HU_EU']

# %%
yields.to_csv('yields.csv')

# %% [markdown]
# Load in Weather Data

# %%
# We'll do precipitation files first

# %%
precip_files = [file for file in os.listdir(os.getcwd() + '\\Weather Data') if file.startswith('pr')]

# %%
precip_df = []

for file in precip_files:
    precip_df.append(pd.read_csv('.\\Weather Data\\' + file, skiprows = 1))

# %%
precip_df_clean = [df[df.columns[1]] for df in precip_df]

# %%
precip_df_concat = pd.concat(precip_df_clean, axis = 1)

# %%
precip_df_concat['Year'] = np.arange(1901, 2022)

precip_df_concat.head()
# Out:
#    Austria  Belgium  Bulgaria  Cyprus  Czech Republic  Germany  Denmark  \
# 0  1052.84   702.00    745.45  282.61          644.96   679.26   623.28
# 1  1061.55   747.48    604.44  517.09          644.66   670.15   571.07
# 2  1201.34   900.16    552.47  408.41          767.25   714.35   751.23
# 3  1146.14   679.13    524.68  586.08          612.23   627.67   596.59
# 4  1127.85   857.02    614.19  513.32          653.02   724.76   678.88
#
#     Spain  Estonia  Finland  ...  Latvia   Malta  Netherlands  Poland  \
# 0  699.90   465.81   414.47  ...  544.84  532.05       703.74  593.49
# 1  695.13   681.50   580.80  ...  679.59  517.00       653.14  602.83
# 2  587.65   701.85   596.31  ...  734.96  357.54       847.83  654.05
# 3  614.72   638.50   534.96  ...  661.88  589.99       610.09  531.73
# 4  559.53   600.57   550.09  ...  654.59  500.78       752.95  648.97
#
#    Portugal  Romania  Slovakia  Slovenia  Sweden  Year
# 0    861.43   746.83    776.19   1610.11  450.41  1901
# 1    982.67   646.03    854.51   1414.19  531.58  1902
# 2    857.42   545.30    891.52   1635.81  611.55  1903
# 3    794.80   533.82    701.77   1531.75  521.95  1904
# 4    713.31   621.53    799.35   1638.73  534.39  1905
#
# [5 rows x 28 columns]

# %%
# Now for mean temperature files
# I'm going to be copy and pasting here but using Hadley Wickhams (Chief Scientist at R Studio) rules of thumb 
# for when to write a function
# I won't write a function seen as I'll be copying and pasting just once
# Hadly Wickham recommends writing a function when you copy and paste more than twice

# %%
temper_files = [file for file in os.listdir(os.getcwd() + '\\Weather Data') if file.startswith('tas')]

# %%
temper_df = []

for file in temper_files:
    temper_df.append(pd.read_csv('.\\Weather Data\\' + file, skiprows = 1))

# %%
temper_df_clean = [df[df.columns[1]] for df in temper_df]

# %%
temper_df_concat = pd.concat(temper_df_clean, axis = 1)

# %%
temper_df_concat['Year'] = np.arange(1901, 2022)

temper_df_concat.head()
# Out:
#    Austria  Belgium  Bulgaria  Cyprus  Czech Republic  Germany  Denmark  \
# 0     5.41     8.89     10.42   17.91            6.76     7.86     7.73
# 1     5.34     8.52      9.78   17.46            6.23     7.37     6.45
# 2     5.88     9.40     10.71   16.69            7.38     8.43     7.67
# 3     6.22     9.38     10.22   17.06            7.51     8.50     7.54
# 4     5.79     9.03     10.41   17.35            7.15     8.09     7.61
#
#    Spain  Estonia  Finland  ...  Latvia  Malta  Netherlands  Poland  Portugal  \
# 0  12.21     5.38     1.50  ...    6.03  18.29         8.87    7.74     14.15
# 1  12.42     3.00    -1.11  ...    3.96  18.40         8.30    6.31     14.27
# 2  12.48     5.82     1.65  ...    6.46  18.00         9.40    8.11     14.45
# 3  12.86     4.14     0.29  ...    4.92  18.29         9.30    7.47     14.78
# 4  12.23     5.18     1.26  ...    5.76  18.02         9.01    7.69     14.13
#
#    Romania  Slovakia  Slovenia  Sweden  Year
# 0     9.17      7.45      7.79    2.32  1901
# 1     8.27      6.57      7.78    0.29  1902
# 2     9.53      7.90      8.28    2.11  1903
# 3     8.91      7.71      8.65    1.28  1904
# 4     9.14      7.60      8.13    1.92  1905
#
# [5 rows x 28 columns]

# %%
# Write out the files

precip_df_concat.to_csv('precipitation.csv')
temper_df_concat.to_csv('temperature.csv')
