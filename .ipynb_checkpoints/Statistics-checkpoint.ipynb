# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os_gva = pd.read_csv('os_gva.csv')

# %%
os_gva.head()
# Out:
#    Unnamed: 0 freq  itm_newa indic_ag     unit geo\TIME_PERIOD  1973  1974  \
# 0       52588    A     20000  PROD_BP  MIO_EUR              AT   NaN   NaN
# 1       52589    A     20000  PROD_BP  MIO_EUR              BE   NaN   NaN
# 2       52590    A     20000  PROD_BP  MIO_EUR              BG   NaN   NaN
# 3       52591    A     20000  PROD_BP  MIO_EUR              CH   NaN   NaN
# 4       52592    A     20000  PROD_BP  MIO_EUR              CY   NaN   NaN
#
#    1975  1976  ...     2012     2013     2014     2015     2016     2017  \
# 0   NaN   NaN  ...  2981.66  2754.18  2728.85  2705.44  2859.12  3221.72
# 1   NaN   NaN  ...  2825.40  2408.47  2244.58  2485.08  2238.38  2471.83
# 2   NaN   NaN  ...  1662.26  1694.36  1731.65  1620.73  1675.58  1792.38
# 3   NaN   NaN  ...  3093.42  3168.18  3500.61  3516.31  3719.59  3502.41
# 4   NaN   NaN  ...   332.81   320.67   267.73   273.54   318.80   321.16
#
#       2018     2019     2020     2021
# ...

# %%
os_gva.drop(columns = ['Unnamed: 0', 'freq'], inplace = True)

# %%
os_gva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   itm_newa         86 non-null     int64
#  1   indic_ag         86 non-null     object
#  2   unit             86 non-null     object
#  3   geo\TIME_PERIOD  86 non-null     object
#  4   1973             6 non-null      float64
#  5   1974             6 non-null      float64
#  6   1975             8 non-null      float64
#  7   1976             10 non-null     float64
#  8   1977             10 non-null     float64
#  9   1978             10 non-null     float64
#  10  1979             10 non-null     float64
#  11  1980             16 non-null     float64
#  12  1981             16 non-null     float64
#  13  1982             16 non-null     float64
#  14  1983             16 non-null     float64
#  15  1984             16 non-null     float64
# ...

# %%
os_gva.itm_newa.replace({20000: 'GVA', 27000: 'OS'}, inplace = True)

# %%
os_gva.rename(columns = {'geo\TIME_PERIOD': 'geo'}, inplace = True)

# %%
os_gva.head()
# Out:
#   itm_newa indic_ag     unit geo  1973  1974  1975  1976  1977  1978  ...  \
# 0      GVA  PROD_BP  MIO_EUR  AT   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      GVA  PROD_BP  MIO_EUR  BE   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      GVA  PROD_BP  MIO_EUR  BG   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      GVA  PROD_BP  MIO_EUR  CH   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      GVA  PROD_BP  MIO_EUR  CY   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       2012     2013     2014     2015     2016     2017     2018     2019  \
# 0  2981.66  2754.18  2728.85  2705.44  2859.12  3221.72  3114.61  3050.94
# 1  2825.40  2408.47  2244.58  2485.08  2238.38  2471.83  2225.64  2627.23
# 2  1662.26  1694.36  1731.65  1620.73  1675.58  1792.38  1732.50  1767.81
# 3  3093.42  3168.18  3500.61  3516.31  3719.59  3502.41  3561.20  3816.50
# 4   332.81   320.67   267.73   273.54   318.80   321.16   308.38   348.05
#
#       2020     2021
# 0  3122.27  3622.44
# 1  2472.33  2570.95
# ...

# %%
os_gva_long = os_gva.melt(id_vars = ['itm_newa', 'indic_ag', 'unit', 'geo'])

# %%
os_gva_long.head()
# Out:
#   itm_newa indic_ag     unit geo variable  value
# 0      GVA  PROD_BP  MIO_EUR  AT     1973    NaN
# 1      GVA  PROD_BP  MIO_EUR  BE     1973    NaN
# 2      GVA  PROD_BP  MIO_EUR  BG     1973    NaN
# 3      GVA  PROD_BP  MIO_EUR  CH     1973    NaN
# 4      GVA  PROD_BP  MIO_EUR  CY     1973    NaN

# %%
os_gva_long.dropna(inplace = True)

# %%
os_gva_long.head()
# Out:
#    itm_newa indic_ag     unit geo variable     value
# 7       GVA  PROD_BP  MIO_EUR  DK     1973   1416.03
# 24      GVA  PROD_BP  MIO_EUR  FR     1973  14156.80
# 42      GVA  PROD_BP  MIO_EUR  UK     1973   3679.67
# 50       OS  PROD_BP  MIO_EUR  DK     1973    981.78
# 67       OS  PROD_BP  MIO_EUR  FR     1973  10772.75

# %%
os_gva_long_wide = os_gva_long.pivot_table(index = ['indic_ag', 'unit', 'geo', 'variable'], 
                                           columns = 'itm_newa', values = 'value')

# %%
os_gva_long_wide.reset_index(inplace = True)

# %%
os_gva_long_wide.head()
# Out:
# itm_newa indic_ag     unit geo variable      GVA       OS
# 0         PROD_BP  MIO_EUR  AT     1990  3215.11  2037.38
# 1         PROD_BP  MIO_EUR  AT     1991  3267.67  2102.16
# 2         PROD_BP  MIO_EUR  AT     1992  3063.35  1938.48
# 3         PROD_BP  MIO_EUR  AT     1993  3114.03  1878.55
# 4         PROD_BP  MIO_EUR  AT     1994  3344.65  2160.74

# %%
os_gva_long_wide['profit_rate'] = os_gva_long_wide.OS/os_gva_long_wide.GVA*100

# %%
os_gva_long_wide.head()
# Out:
# itm_newa indic_ag     unit geo variable      GVA       OS  profit_rate
# 0         PROD_BP  MIO_EUR  AT     1990  3215.11  2037.38    63.368905
# 1         PROD_BP  MIO_EUR  AT     1991  3267.67  2102.16    64.332078
# 2         PROD_BP  MIO_EUR  AT     1992  3063.35  1938.48    63.279743
# 3         PROD_BP  MIO_EUR  AT     1993  3114.03  1878.55    60.325366
# 4         PROD_BP  MIO_EUR  AT     1994  3344.65  2160.74    64.602873

# %%
os_gva_plot1_data = os_gva_long_wide[(os_gva_long_wide.geo.isin(['AT', 'BE', 'DE', 'DK', 'EU27_2020', 'IE', 'NL', 'UK'])) &
                                      (os_gva_long_wide.variable >= '1990') & (os_gva_long_wide.variable <= '2021')]

# %%
f, ax = plt.subplots(figsize = (15, 10))

ax = sns.lineplot(x = 'variable', y = 'profit_rate', hue = 'geo', data = os_gva_plot1_data)

plt.setp(ax.get_xticklabels(), rotation = 45)

plt.show()

# %%
os_gva_average = os_gva_long_wide.groupby('geo').mean().reset_index()

# %%
eu27_codes = ['AT', 'BE', 'BG', 'HR', 'CY', 'CZ', 'DK', 'EE', 'FI', 'FR', 'DE', 'EL', 'HU', 'IE', 'IT', 'LV', 'LT',
              'LU', 'MT', 'NL', 'PL', 'PT', 'RO', 'SK', 'SI', 'ES', 'SE']

os_gva_average_eu27 = os_gva_average[os_gva_average.geo.isin(eu27_codes)].sort_values('profit_rate')

# %%
f, ax = plt.subplots(figsize = (15, 10))

ax = sns.barplot(x = 'geo', y = 'profit_rate', data = os_gva_average_eu27)

plt.show()
